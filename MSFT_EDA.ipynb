# %% [markdown]
# # <font color=red> EDA on 1 day interval Stock Dataset </font>

# %% [markdown]
# # Before starting with any project! we should import the libraries required

# %%
import pandas as pd #for data manipulation
import numpy as np #numerical computation
import seaborn as sns #visualization 
import matplotlib.pyplot as plt #visualization
print("Libraries are imported successfully")
# Out:
# Libraries are imported successfully

# %%
data=pd.read_csv("MSFT.csv")
print("Dataset is imported")
# Out:
# Dataset is imported

# %% [markdown]
# # Once the dataset is imported, we have to check if it is correctly imported or not by checking the rows of the dataset

# %%
data.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.062302    47894400

# %% [markdown]
# # Dataset is correctly imported

# %% [markdown]
# # Let us check all the datatypes for all the column

# %%
a=data['Date'].dtype
print("The datatype of date is:{}".format(a))
b=data['Open'].dtype
print("The datatype of open is:{}".format(b))
c=data['High'].dtype
print('The datatype of high is: {}'.format(c))
d=data['Low'].dtype
print("The datatype of low is: {}".format(d))
e=data['Close'].dtype
print("The datatype of close is:{}".format(e))
f=data['Adj Close'].dtype
print("The datatype of adj close is:{}".format(f))
g=data['Volume'].dtype
print("The datatype of volume is:{}".format(g))
# Out:
# The datatype of date is:object
# The datatype of open is:float64
# The datatype of high is: float64
# The datatype of low is: float64
# The datatype of close is:float64
# The datatype of adj close is:float64
# The datatype of volume is:int64

# %% [markdown]
# ## The datatype of date should be Datetime not object.

# %% [markdown]
# # Lets check if there are any null values in our dataset

# %%
null_a=data.isnull().sum()
print("Null values:{}".format(null_a))
# Out:
# Null values:Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %% [markdown]
# # no null values

# %% [markdown]
# # Let us convert Datatype of date into datetime

# %%
data_new=data #keep the original data uneffected, we will copy into new variable
data_new.head()
# Out:
#          Date      Open      High       Low     Close  Adj Close      Volume
# 0  1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1  1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2  1986-03-17  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3  1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4  1986-03-19  0.099826  0.100694  0.097222  0.098090   0.062302    47894400

# %%
data_new['Date']=pd.to_datetime(data_new['Date'])
data_new.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close      Volume
# 0 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.062302    47894400

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8857 entries, 0 to 8856
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8857 non-null   datetime64[ns]
#  1   Open       8857 non-null   float64
#  2   High       8857 non-null   float64
#  3   Low        8857 non-null   float64
#  4   Close      8857 non-null   float64
#  5   Adj Close  8857 non-null   float64
#  6   Volume     8857 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 484.5 KB

# %% [markdown]
# # we can observe date datatype is changed to datetime

# %%
data_new['Day']=data_new['Date'].dt.day
data_new['Month']=data_new['Date'].dt.month
data_new['Year']=data_new['Date'].dt.year
data_new.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close      Volume  \
# 0 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.062302    47894400
#
#    Day  Month  Year
# 0   13      3  1986
# 1   14      3  1986
# 2   17      3  1986
# 3   18      3  1986
# 4   19      3  1986

# %%
data_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8857 entries, 0 to 8856
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       8857 non-null   datetime64[ns]
#  1   Open       8857 non-null   float64
#  2   High       8857 non-null   float64
#  3   Low        8857 non-null   float64
#  4   Close      8857 non-null   float64
#  5   Adj Close  8857 non-null   float64
#  6   Volume     8857 non-null   int64
#  7   Day        8857 non-null   int64
#  8   Month      8857 non-null   int64
#  9   Year       8857 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(4)
# memory usage: 692.1 KB

# %% [markdown]
# # CALCULATING DAILY RETURNS
# ## First, we will create the column ‘Daily Lag’ which is basically just shifting the ‘Close’ price by one day back

# %%
data_new['Daily Lag'] = data_new['Close'].shift(1)
data_new.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close      Volume  \
# 0 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.062302    47894400
#
#    Day  Month  Year  Daily Lag
# 0   13      3  1986        NaN
# 1   14      3  1986   0.097222
# 2   17      3  1986   0.100694
# 3   18      3  1986   0.102431
# 4   19      3  1986   0.099826

# %%
data_new['Daily Returns'] = (data_new['Daily Lag']/data_new['Close']) -1
data_new.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close      Volume  \
# 0 1986-03-13  0.088542  0.101563  0.088542  0.097222   0.061751  1031788800
# 1 1986-03-14  0.097222  0.102431  0.097222  0.100694   0.063956   308160000
# 2 1986-03-17  0.100694  0.103299  0.100694  0.102431   0.065059   133171200
# 3 1986-03-18  0.102431  0.103299  0.098958  0.099826   0.063405    67766400
# 4 1986-03-19  0.099826  0.100694  0.097222  0.098090   0.062302    47894400
#
#    Day  Month  Year  Daily Lag  Daily Returns
# 0   13      3  1986        NaN            NaN
# 1   14      3  1986   0.097222      -0.034481
# 2   17      3  1986   0.100694      -0.016958
# 3   18      3  1986   0.102431       0.026095
# 4   19      3  1986   0.099826       0.017698

# %%
mean = data_new['Daily Returns'].mean()
std = data_new['Daily Returns'].std()
print('Mean =',mean)
print('Standard deviation =',std)
# Out:
# Mean = -0.0006542327903949583
# Standard deviation = 0.02171160918684973

# %%
plt.figure(figsize=(15,6))
data_new['Daily Returns'].hist(bins=20)
plt.axvline(mean,color='red', linestyle='dashed', linewidth=2)
#to plot the std line we plot both the positive and negative values 
plt.axvline(std,color='g',linestyle='dashed',linewidth=2)
plt.axvline(-std,color='g',linestyle='dashed',linewidth=2)

# %% [markdown]
# # lets start with EDA
#
# <font color= green> EDA refers to set of tools that analyze data merely to explore it for future analysis </font>

# %%
data_new.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  8857.000000  8857.000000  8857.000000  8857.000000  8857.000000
# mean     34.831233    35.209355    34.449657    34.840895    29.886536
# std      44.060163    44.513443    43.597704    44.080986    44.195101
# min       0.088542     0.092014     0.088542     0.090278     0.057340
# 25%       3.843750     3.875000     3.812500     3.851563     2.446323
# 50%      26.590000    26.879999    26.290001    26.590000    18.686628
# 75%      36.730000    37.000000    36.110001    36.660000    27.218300
# max     261.660004   263.190002   260.170013   261.970001   261.970001
#
#              Volume          Day        Month         Year    Daily Lag  \
# count  8.857000e+03  8857.000000  8857.000000  8857.000000  8856.000000
# mean   5.953411e+07    15.743480     6.527831  2003.245907    34.816389
# std    3.858121e+07     8.748036     3.427685    10.153988    44.023101
# ...

# %%
range_open=data_new['Open'].max()-data_new['Open'].min()
print("The range for open: {}".format(range_open))
range_high=data_new['High'].max()-data_new['High'].min()
print("The range for high: {}".format(range_high))
range_low=data_new['Low'].max()-data_new['Low'].min()
print("The range for low: {}".format(range_low))
range_close=data_new['Close'].max()-data_new['Close'].min()
print("The range for close: {}".format(range_close))
#range_lag=data_new['Daily Lag'].max()-data_new['Daily Lag'].min()
#print("The range of lag is : {}".format(range_lag))
#range_return=data_new['Daily Returns'].max()-data_new['Daily Returns'].min()
#print("The range of return is : {}".format(range_return))
# Out:
# The range for open: 261.57146166265017
# The range for high: 263.0979884415865
# The range for low: 260.08147142827517
# The range for close: 261.87972322106356

# %% [markdown]
# # Let us scale the dataset so that the values fall in the range 0 to 1

# %%
from sklearn.preprocessing import MinMaxScaler
mm=MinMaxScaler()
data_new['Open']=mm.fit_transform(data_new['Open'].values.reshape(-1,1))
data_new['High']=mm.fit_transform(data_new['High'].values.reshape(-1,1))
data_new['Low']=mm.fit_transform(data_new['Low'].values.reshape(-1,1))
data_new['Close']=mm.fit_transform(data_new['Close'].values.reshape(-1,1))
data_new['Adj Close']=mm.fit_transform(data_new['Adj Close'].values.reshape(-1,1))
data_new['Volume']=mm.fit_transform(data_new['Volume'].values.reshape(-1,1))
#data_new['Daily Lag']=mm.fit_transform(data_new['Daily Lag'].values.reshape(-1,1))
#data_new['Daily Returns']=mm.fit_transform(data_new['Daily Returns'].values.reshape(-1,1))

# %%
data_new.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  8857.000000  8857.000000  8857.000000  8857.000000  8857.000000
# mean      0.132823     0.133476     0.132117     0.132697     0.113890
# std       0.168444     0.169190     0.167631     0.168325     0.168740
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.014356     0.014379     0.014318     0.014363     0.009121
# 50%       0.101316     0.101818     0.100743     0.101190     0.071128
# 75%       0.140082     0.140282     0.138501     0.139643     0.103702
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#             Volume          Day        Month         Year    Daily Lag  \
# count  8857.000000  8857.000000  8857.000000  8857.000000  8856.000000
# mean      0.055591    15.743480     6.527831  2003.245907    34.816389
# std       0.037476     8.748036     3.427685    10.153988    44.023101
# ...

# %% [markdown]
# # lets build a boxplot, this will describe the 5 number summary

# %%
sns.boxplot(data_new['Open'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Open'>

# %%
IQR=data_new['Open'].quantile(0.75)-data_new['Open'].quantile(0.25)
print("The inter quartile range is: {}".format(IQR))
# Out:
# The inter quartile range is: 0.12572567868527595

# %% [markdown]
# # Detect outlier in open column

# %%
outlier=data_new['Open'].quantile(0.75)+1.5*IQR
print("The outlier in open column start from:{}".format(outlier))
# Out:
# The outlier in open column start from:0.32867053351182673

# %%
sns.boxplot(data_new['High'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='High'>

# %%
IQR=data_new['High'].quantile(0.75)-data_new['High'].quantile(0.25)
print("The inter quartile range is: {}".format(IQR))
# Out:
# The inter quartile range is: 0.12590366120322685

# %%
outlier=data_new['High'].quantile(0.75)+1.5*IQR
print("The outlier in high column start from:{}".format(outlier))
# Out:
# The outlier in high column start from:0.3291377730142028

# %%
sns.boxplot(data_new['Low'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Low'>

# %%
IQR=data_new['Low'].quantile(0.75)-data_new['Low'].quantile(0.25)
print("The inter quartile range is: {}".format(IQR))
outlier=data_new['Low'].quantile(0.75)+1.5*IQR
print("The outlier in low column start from:{}".format(outlier))
# Out:
# The inter quartile range is: 0.12418224348310992
# The outlier in low column start from:0.3247740373912565

# %%
sns.boxplot(data_new['Close'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close'>

# %%
IQR=data_new['Close'].quantile(0.75)-data_new['Close'].quantile(0.25)
print("The inter quartile range is: {}".format(IQR))
outlier=data_new['Close'].quantile(0.75)+1.5*IQR
print("The outlier in close column start from:{}".format(outlier))
# Out:
# The inter quartile range is: 0.12528055424466744
# The outlier in close column start from:0.3275640286255479

# %%
sns.boxplot(data_new['Volume'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Volume'>

# %%
IQR=data_new['Volume'].quantile(0.75)-data_new['Volume'].quantile(0.25)
print("The inter quartile range is: {}".format(IQR))
outlier=data_new['Volume'].quantile(0.75)+1.5*IQR
print("The outlier in volume column start from:{}".format(outlier))
# Out:
# The inter quartile range is: 0.036715452233971796
# The outlier in volume column start from:0.12412830184573878

# %%
IQR=data_new['Daily Lag'].quantile(0.75)-data_new['Daily Lag'].quantile(0.25)
print("The inter quartile range is: {}".format(IQR))
outlier=data_new['Daily Lag'].quantile(0.75)+1.5*IQR
print("The outlier in Daily Lag column start from:{}".format(outlier))
# Out:
# The inter quartile range is: 32.79538977146149
# The outlier in Daily Lag column start from:85.83808416128159

# %%
IQR=data_new['Daily Returns'].quantile(0.75)-data_new['Daily Returns'].quantile(0.25)
print("The inter quartile range is: {}".format(IQR))
outlier=data_new['Daily Returns'].quantile(0.75)+1.5*IQR
print("The outlier in Returns column start from:{}".format(outlier))
# Out:
# The inter quartile range is: 0.0205218279029121
# The outlier in Returns column start from:0.04016446761966837

# %%
plt.subplot(1,2,1)
sns.boxplot(data_new['Daily Lag'])
plt.title("Boxplot of lag column")
print("The maximum value of lag column is",data_new['Daily Lag'].max())

plt.subplot(1,2,2)
sns.boxplot(data_new['Daily Returns'])
plt.title("Boxplot of return column")
print("The maximum value of return column is",data_new['Daily Returns'].max())
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# The maximum value of lag column is 261.97000122070307
# The maximum value of return column is 0.43094050555718355

# %%
sns.set_style("darkgrid")
plt.figure(figsize=(20,10))
sns.lineplot(data_new['Year'],data_new['Open'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='Open'>

# %% [markdown]
# # Looking at the graph we can observe that the opening value of the stock of the company has took a huge jump from 2014-2015

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data_new['Year'],data_new['High'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='High'>

# %%
plt.figure(figsize=(20,15))
sns.lineplot(data_new['Year'],data_new['Volume'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Year', ylabel='Volume'>

# %%
# Daywise Stock Closing Prices
plt.figure(figsize=(20,6))
sns.lineplot(x="Close",y="Volume", label="Volume", data=data_new, color="Yellow")
# Out:
# <AxesSubplot:xlabel='Close', ylabel='Volume'>

# %% [markdown]
# # Volume is decreasing year by year

# %%
plt.figure(figsize=(20,10))
sns.lineplot(data_new['Date'],data_new['Open'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
#sns.catplot(x='Day',y='Open',hue='Month',data=data_new,col='Year',kind="point")

# %% [markdown]
# # April month in 2021 has highest opening

# %% [markdown]
# # As we go on looking at the years, the opening price is going high and high
# 1) Year 2013 2014 and 2015 were significant because the opening price started to rise good
# 2) Year 1998,1999 and 2000 were also had good opening when compared to previous years

# %% [markdown]
# # Correlation

# %%
data_new.corr()
# Out:
#                    Open      High       Low     Close  Adj Close    Volume  \
# Open           1.000000  0.999916  0.999911  0.999832   0.995506 -0.299034
# High           0.999916  1.000000  0.999861  0.999904   0.995460 -0.296961
# Low            0.999911  0.999861  1.000000  0.999915   0.995702 -0.301166
# Close          0.999832  0.999904  0.999915  1.000000   0.995680 -0.299194
# Adj Close      0.995506  0.995460  0.995702  0.995680   1.000000 -0.303573
# Volume        -0.299034 -0.296961 -0.301166 -0.299194  -0.303573  1.000000
# Day            0.003261  0.003116  0.003098  0.002875   0.002837  0.015174
# Month         -0.012139 -0.012588 -0.011748 -0.012190  -0.012428 -0.067518
# Year           0.729273  0.728591  0.729958  0.729225   0.707261 -0.319164
# Daily Lag      0.999891  0.999824  0.999799  0.999696   0.995365 -0.307816
# Daily Returns  0.002883 -0.000748 -0.001436 -0.005885  -0.007174  0.035721
#
# ...

# %% [markdown]
# # Suppose we are predicting the future 30 day's open price using regression we have to look at correlation... which attribute will effect our target (here Open)
#
# ## Looking at the correlation table
# ###  Open is closely related to High,Low,Close, Adj Close and year

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data_new.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Based on previous day's Close, we may say that next day's opening will be related

# %%
sns.clustermap(data_new.corr(),annot=True)

# %%
sns.distplot(data_new['Close'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Close', ylabel='Density'>

# %%
data_new['Close'].skew()
# Out:
# 2.636472983905205

# %% [markdown]
# # Right Skewed

# %% [markdown]
# # Skewness is a measure of the asymmetry of the probability distribution of a real-valued random variable about its mean.

# %%
data_new['Open'].skew()
# Out:
# 2.6349529102250155

# %% [markdown]
# # Right Skewed

# %%
sns.regplot(data_new['Close'],data_new['Open'])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Close', ylabel='Open'>

# %% [markdown]
# # KURTOSIS VALUE

# %%
data_new['Daily Returns'].kurtosis()
# Out:
# 24.32932200363173

# %% [markdown]
# ![download.png](attachment:download.png)
#
# # Here, kurtosis tells us the ‘fatness’ of the tail and it is important because it tells you how ‘extreme’ can the values get. In our case, the value is positive, so this indicates that the chance of ‘extreme’ values are rare.

# %% [markdown]
# # let us divide the data, for better understanding of line plot

# %%
divide_data=data_new.iloc[0:400,]
divide_data.head()
# Out:
#         Date      Open      High       Low     Close  Adj Close    Volume  \
# 0 1986-03-13  0.000000  0.000036  0.000000  0.000027   0.000017  1.000000
# 1 1986-03-14  0.000033  0.000040  0.000033  0.000040   0.000025  0.297096
# 2 1986-03-17  0.000046  0.000043  0.000047  0.000046   0.000029  0.127119
# 3 1986-03-18  0.000053  0.000043  0.000040  0.000036   0.000023  0.063588
# 4 1986-03-19  0.000043  0.000033  0.000033  0.000030   0.000019  0.044285
#
#    Day  Month  Year  Daily Lag  Daily Returns
# 0   13      3  1986        NaN            NaN
# 1   14      3  1986   0.097222      -0.034481
# 2   17      3  1986   0.100694      -0.016958
# 3   18      3  1986   0.102431       0.026095
# 4   19      3  1986   0.099826       0.017698

# %%
divide_data.shape
# Out:
# (400, 12)

# %%
divide_data.tail()
# Out:
#           Date      Open      High       Low     Close  Adj Close    Volume  \
# 395 1987-10-05  0.001613  0.001735  0.001622  0.001750   0.001111  0.176803
# 396 1987-10-06  0.001759  0.001742  0.001619  0.001611   0.001023  0.194987
# 397 1987-10-07  0.001626  0.001636  0.001569  0.001591   0.001010  0.119804
# 398 1987-10-08  0.001606  0.001610  0.001515  0.001565   0.000994  0.091926
# 399 1987-10-09  0.001580  0.001636  0.001575  0.001558   0.000989  0.088961
#
#      Day  Month  Year  Daily Lag  Daily Returns
# 395    5     10  1987   0.503472      -0.082279
# 396    6     10  1987   0.548611       0.071186
# 397    7     10  1987   0.512153       0.010275
# 398    8     10  1987   0.506944       0.013888
# 399    9     10  1987   0.500000       0.003484

# %%
sns.set_color_codes(palette='bright')
plt.figure(figsize=(20,10))
sns.lineplot(divide_data['Date'],divide_data['Open'],hue=divide_data['Year'],palette=["C3", "C19"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %% [markdown]
# # the dataset is dated from 1986 march month till 1987 october

# %% [markdown]
# # in the year 1986, the open stock was too low , but in october month it rised good .. from october till the end of the year 1986 open stock price  went rising

# %% [markdown]
# # In the year 1987,the open price went on rising from month of january to may, but in may,june,july and august the price fell and and again in september price were high

# %%
plt.figure(figsize=(15,10))
sns.lineplot(divide_data['Date'],divide_data['Close'],hue=divide_data['Year'],palette=["C3", "C19"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Close'>

# %% [markdown]
# # Very similar trends can be seen between Open and close

# %%
divide_data1=data_new.iloc[440:880,]
divide_data1.head()
# Out:
#           Date      Open      High       Low     Close  Adj Close    Volume  \
# 440 1987-12-08  0.000810  0.000904  0.000808  0.000915   0.000581  0.107061
# 441 1987-12-09  0.000916  0.000924  0.000888  0.000882   0.000560  0.079156
# 442 1987-12-10  0.000869  0.000957  0.000841  0.000915   0.000581  0.158619
# 443 1987-12-11  0.000929  0.000930  0.000908  0.000928   0.000589  0.068161
# 444 1987-12-14  0.000936  0.000996  0.000935  0.001001   0.000636  0.090150
#
#      Day  Month  Year  Daily Lag  Daily Returns
# 440    8     12  1987   0.300347      -0.089474
# 441    9     12  1987   0.329861       0.027025
# 442   10     12  1987   0.321181      -0.026314
# 443   11     12  1987   0.329861      -0.010416
# 444   14     12  1987   0.333333      -0.054189

# %%
divide_data1.shape
# Out:
# (440, 12)

# %%
plt.figure(figsize=(15,10))
sns.lineplot(divide_data1['Date'],divide_data1['Open'],hue=divide_data1['Year'],palette=["C3", "C19","C8"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %% [markdown]
# # 1) Year 1987 ended in a very positive note
# # 2) Year 1988 started good, but in the month of feb stock fell and then a good gain until mid august and year 1988 ended not as good
# # 3) Year 1989 had a pretty good start but the open price well in mid march and recovered good in june

# %%
divide_data2=data_new.iloc[880:1800,]
divide_data2.head()
# Out:
#           Date      Open      High       Low     Close  Adj Close    Volume  \
# 880 1989-09-05  0.001248  0.001260  0.001252  0.001246   0.000792  0.088429
# 881 1989-09-06  0.001248  0.001234  0.001228  0.001226   0.000779  0.038927
# 882 1989-09-07  0.001228  0.001214  0.001208  0.001200   0.000762  0.038466
# 883 1989-09-08  0.001201  0.001221  0.001202  0.001220   0.000775  0.036410
# 884 1989-09-11  0.001221  0.001221  0.001222  0.001230   0.000781  0.024870
#
#      Day  Month  Year  Daily Lag  Daily Returns
# 880    5      9  1989   0.415799      -0.002083
# 881    6      9  1989   0.416667       0.012660
# 882    7      9  1989   0.411458       0.017166
# 883    8      9  1989   0.404514      -0.012711
# 884   11      9  1989   0.409722      -0.006315

# %%
divide_data2.shape
# Out:
# (920, 12)

# %%
plt.figure(figsize=(25,10))
sns.lineplot(divide_data2['Date'],divide_data2['Open'],hue=divide_data2['Year'],palette=["C3", "C19",'C4',"C6","C10"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %%
divide_data3=data_new.iloc[1800:3200,]
divide_data3.head()
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 1800 1993-04-26  0.009398  0.009449  0.009242  0.009246   0.005872  0.061266
# 1801 1993-04-27  0.009279  0.009479  0.009302  0.009500   0.006033  0.054303
# 1802 1993-04-28  0.009578  0.009865  0.009602  0.009918   0.006298  0.051549
# 1803 1993-04-29  0.009906  0.009835  0.009753  0.009858   0.006260  0.046000
# 1804 1993-04-30  0.009816  0.009954  0.009873  0.009858   0.006260  0.043246
#
#       Day  Month  Year  Daily Lag  Daily Returns
# 1800   26      4  1993   2.542969       0.012442
# 1801   27      4  1993   2.511719      -0.025757
# 1802   28      4  1993   2.578125      -0.040698
# 1803   29      4  1993   2.687500       0.005848
# 1804   30      4  1993   2.671875       0.000000

# %%
divide_data3.shape
# Out:
# (1400, 12)

# %%
divide_data3.tail()
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 3195 1998-10-30  0.102167  0.102452  0.100710  0.100727   0.063969  0.055386
# 3196 1998-11-02  0.101331  0.101205  0.100589  0.100668   0.063931  0.044765
# 3197 1998-11-03  0.100494  0.100908  0.100349  0.100071   0.063552  0.033262
# 3198 1998-11-04  0.100793  0.101620  0.100469  0.100369   0.063742  0.063290
# 3199 1998-11-05  0.100315  0.101917  0.100830  0.101205   0.064272  0.072292
#
#       Day  Month  Year  Daily Lag  Daily Returns
# 3195   30     10  1998  26.656250       0.007084
# 3196    2     11  1998  26.468750       0.000591
# 3197    3     11  1998  26.453125       0.005942
# 3198    4     11  1998  26.296875      -0.002962
# 3199    5     11  1998  26.375000      -0.008226

# %%
plt.figure(figsize=(20,10))
sns.lineplot(divide_data3['Date'],divide_data3['Open'],hue=divide_data3['Year'],palette=["C3", "C19","C12","C4","C15","C8"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %% [markdown]
# # Year 1994 and 1995 had steady growth of Open price
# # Year 1996 and 1997 were good for the market
# # Year 1997 to 1999 the growth were significant at that time

# %%
divide_data4=data_new.iloc[3200:5500,]
divide_data4.head()
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 3200 1998-11-06  0.101032  0.103937  0.101491  0.104009   0.066053  0.070091
# 3201 1998-11-09  0.104019  0.105481  0.104254  0.105322   0.066887  0.064744
# 3202 1998-11-10  0.104915  0.107440  0.105456  0.106634   0.067720  0.067773
# 3203 1998-11-11  0.108081  0.108688  0.106237  0.105680   0.067114  0.059831
# 3204 1998-11-12  0.105034  0.105243  0.103954  0.103472   0.065712  0.035185
#
#       Day  Month  Year  Daily Lag  Daily Returns
# 3200    6     11  1998  26.593750      -0.026872
# 3201    9     11  1998  27.328125      -0.012422
# 3202   10     11  1998  27.671875      -0.012270
# 3203   11     11  1998  28.015625       0.009004
# 3204   12     11  1998  27.765625       0.021264

# %%
divide_data4.tail()
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 5495 2007-12-24  0.137788  0.139218  0.138270  0.139338   0.103901  0.026536
# 5496 2007-12-26  0.138859  0.138914  0.139077  0.139452   0.103986  0.027148
# 5497 2007-12-27  0.138629  0.138572  0.137847  0.137008   0.102164  0.030119
# 5498 2007-12-28  0.137673  0.137356  0.136809  0.137581   0.102591  0.030251
# 5499 2007-12-31  0.136909  0.136443  0.136232  0.135596   0.101111  0.031983
#
#       Day  Month  Year  Daily Lag  Daily Returns
# 5495   24     12  2007  36.060001      -0.014215
# 5496   26     12  2007  36.580002      -0.000819
# 5497   27     12  2007  36.610001       0.017793
# 5498   28     12  2007  35.970001      -0.004153
# 5499   31     12  2007  36.119999       0.014607

# %%
divide_data4['Year'].value_counts()
# Out:
# 2005    252
# 2003    252
# 1999    252
# 2004    252
# 2002    252
# 2000    252
# 2007    251
# 2006    251
# 2001    248
# 1998     38
# Name: Year, dtype: int64

# %%
plt.figure(figsize=(25,10))
sns.lineplot(divide_data4['Date'],divide_data4['Open'],hue=divide_data4['Year'],palette=["C1","C2","C3","C4","C5","C6","C7","C8","C9","C10"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %% [markdown]
# # Similar trends for both open and close
#
# # The stock price were performing good from 1999 to 2000 and started to fall very bad in 2001, The open and close price were very bad till 2007 august-september and took a good leap ahead till the end of year 2007

# %%
divide_data5=data_new.iloc[5500:7000,]
divide_data5.head()
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 5500 2008-01-02  0.136488  0.136329  0.134233  0.134144   0.100030  0.058962
# 5501 2008-01-03  0.134309  0.135151  0.133694  0.134717   0.100457  0.045941
# 5502 2008-01-04  0.134195  0.133441  0.130734  0.130937   0.097639  0.067788
# 5503 2008-01-07  0.131748  0.131920  0.131349  0.131815   0.098293  0.075630
# 5504 2008-01-08  0.132359  0.131578  0.128081  0.127386   0.094992  0.074643
#
#       Day  Month  Year  Daily Lag  Daily Returns
# 5500    2      1  2008  35.599998       0.010789
# 5501    3      1  2008  35.220001      -0.004241
# 5502    4      1  2008  35.369999       0.028796
# 5503    7      1  2008  34.380001      -0.006645
# 5504    8      1  2008  34.610001       0.034679

# %%
divide_data5.tail()
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 6995 2013-12-09  0.147078  0.147390  0.147190  0.147471   0.127283  0.027181
# 6996 2013-12-10  0.147269  0.147504  0.145845  0.145180   0.125307  0.034507
# 6997 2013-12-11  0.145167  0.145223  0.143422  0.143271   0.123660  0.036474
# 6998 2013-12-12  0.143561  0.142715  0.142615  0.141782   0.122376  0.032743
# 6999 2013-12-13  0.142720  0.141993  0.140462  0.139758   0.120630  0.036681
#
#       Day  Month  Year  Daily Lag  Daily Returns
# 6995    9     12  2013  38.360001      -0.009042
# 6996   10     12  2013  38.709999       0.015744
# 6997   11     12  2013  38.110001       0.013294
# 6998   12     12  2013  37.610001       0.010478
# 6999   13     12  2013  37.220001       0.014445

# %%
divide_data5['Year'].unique()
# Out:
# array([2008, 2009, 2010, 2011, 2012, 2013], dtype=int64)

# %%
plt.figure(figsize=(25,15))
sns.lineplot(divide_data5['Date'],divide_data5['Open'],hue=divide_data5['Year'],palette=["C3", "C19","C4","C14","C10","C8"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %% [markdown]
# # From the rise in 2008 to fall in 2009
# # But the market recovered from the fall in Feb-March and took huge jump ahead and continued to be in good shape till 2012
# # 2012 and 2013 had good shape going up

# %%
divide_data6=data_new.iloc[7000:8000,]
divide_data6.tail()
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 7995 2017-11-28  0.321065  0.322952  0.322712  0.323774   0.309698  0.019060
# 7996 2017-11-29  0.323512  0.322420  0.319482  0.317893   0.304075  0.024359
# 7997 2017-11-30  0.318924  0.320899  0.320098  0.321062   0.307105  0.029870
# 7998 2017-12-01  0.319268  0.322002  0.319636  0.321406   0.307434  0.026448
# 7999 2017-12-04  0.322403  0.320557  0.309947  0.309263   0.295823  0.035737
#
#       Day  Month  Year  Daily Lag  Daily Returns
# 7995   28     11  2017  83.870003      -0.011899
# 7996   29     11  2017  84.879997       0.018479
# 7997   30     11  2017  83.339996      -0.009861
# 7998    1     12  2017  84.169998      -0.001068
# 7999    4     12  2017  84.260002       0.039221

# %%
divide_data6['Year'].unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017], dtype=int64)

# %%
plt.figure(figsize=(25,12))
sns.lineplot(divide_data6['Date'],divide_data6['Open'],hue=divide_data6['Year'],palette=["C3", "C19","C1","C2","C4"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %% [markdown]
# # Market kept on rising and has a positive trend with some negative trends

# %%
divide_data7=data_new.iloc[8000:8510,]
divide_data7.tail()
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 8505 2019-12-09  0.577209  0.578180  0.579901  0.577631   0.570312  0.013971
# 8506 2019-12-10  0.578050  0.576964  0.579324  0.576752   0.569445  0.013766
# 8507 2019-12-11  0.579006  0.576888  0.577671  0.578929   0.571593  0.016079
# 8508 2019-12-12  0.579427  0.582855  0.580324  0.584809   0.577398  0.021669
# 8509 2019-12-13  0.584588  0.588366  0.587283  0.589735   0.582261  0.020924
#
#       Day  Month  Year   Daily Lag  Daily Returns
# 8505    9     12  2019  151.750000       0.002577
# 8506   10     12  2019  151.360001       0.001522
# 8507   11     12  2019  151.130005      -0.003757
# 8508   12     12  2019  151.699997      -0.010050
# 8509   13     12  2019  153.240005      -0.008348

# %%
divide_data7['Year'].unique()
# Out:
# array([2017, 2018, 2019], dtype=int64)

# %%
plt.figure(figsize=(27,14))
sns.lineplot(divide_data7['Date'],divide_data7['Open'],hue=divide_data7['Year'],palette=["C3", "C19","C12"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %% [markdown]
# # Market went down in the end of 2018 but started to rise in 2019 and kept on going high till the end of 2019

# %%
divide_data8=data_new.iloc[8510:,]
divide_data8.tail()
# Out:
#            Date      Open      High       Low     Close  Adj Close    Volume  \
# 8852 2021-04-27  0.999694  1.000000  0.999808  1.000000   1.000000  0.027888
# 8853 2021-04-28  0.978667  0.974724  0.972239  0.971705   0.971708  0.043322
# 8854 2021-04-29  0.976297  0.973052  0.957052  0.963877   0.963881  0.037189
# 8855 2021-04-30  0.954429  0.961573  0.959359  0.962616   0.962621  0.027805
# 8856 2021-05-03  0.968422  0.966400  0.965203  0.961394   0.961399  0.016800
#
#       Day  Month  Year   Daily Lag  Daily Returns
# 8852   27      4  2021  261.549988      -0.001603
# 8853   28      4  2021  261.970001       0.029109
# 8854   29      4  2021  254.559998       0.008119
# 8855   30      4  2021  252.509995       0.001309
# 8856    3      5  2021  252.179993       0.001271

# %%
divide_data8['Year'].unique()
# Out:
# array([2019, 2020, 2021], dtype=int64)

# %%
plt.figure(figsize=(25,15))
sns.lineplot(divide_data8['Date'],divide_data8['Open'],hue=divide_data8['Year'],palette=["C3", "C19","C13"])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Date', ylabel='Open'>

# %% [markdown]
# # The market kept rising until 2020 april and then recovered and kept on rising until the end of 2020
# # 2021 began with a low dip in jan and started to rise and until last data we can observe that the market was in good shape

# %%
#data=pd.read_csv("MSFT.csv",index_col='Date')
#data.head()

# %%
#x=data[['Open','High','Low','Adj Close','Volume']]
#y=data[['Close']]

# %%
#from sklearn.model_selection import TimeSeriesSplit
#n_splits=1
#trainTestSplit=TimeSeriesSplit(n_splits+1).split(data)
#next(trainTestSplit)
#for train_index,test_index in trainTestSplit:
 #   xtrain,ytrain=x.iloc[train_index],y.iloc[train_index]
 #   xtest,ytest=x.iloc[test_index],y.iloc[test_index]
 #   test_length=len(xtest)
 #   trainsplit=[(list(range(train_index[0],train_index[-test_length])),
  #                   list(range(train_index[-test_length],train_index[-1]+1)))]

# %%
#xtrain.tail()

# %%
#ytest.tail()

# %%
#xtest.shape,xtrain.shape

# %%
#from sklearn.svm import SVR
#svr_rbf=SVR(kernel='rbf')
#svr_rbf.fit(xtrain,ytrain)

# %%
#ypred=svr_rbf.predict(xtest)

# %%
#from sklearn.metrics import mean_squared_error as mse
#np.sqrt(mse(ypred,ytest))

# %%
#xtest.head(2)

# %%
#svr_poly2=SVR(kernel='poly',degree=4)
#svr_poly2.fit(xtrain,ytrain)

# %%
#ypoly=svr_poly2.predict(xtest)
#ypoly

# %%
#np.sqrt(mse(ypoly,ytest))

# %%
#data_new.head()

# %%
x=data_new[['Day','Month','Year','Open']]
y=data_new[['Close']]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=.3,shuffle=False)

# %%
xtrain.tail()
# Out:
#       Day  Month  Year      Open
# 6194    4     10  2010  0.091262
# 6195    5     10  2010  0.091644
# 6196    6     10  2010  0.092638
# 6197    7     10  2010  0.093785
# 6198    8     10  2010  0.093785

# %%
xtest.head()
# Out:
#       Day  Month  Year      Open
# 6199   11     10  2010  0.094244
# 6200   12     10  2010  0.093900
# 6201   13     10  2010  0.095314
# 6202   14     10  2010  0.096346
# 6203   15     10  2010  0.096614

# %%
from sklearn.svm import SVR 
svr=SVR(kernel='sigmoid')
svr.fit(xtrain,ytrain)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR(kernel='sigmoid')

# %%
ypred=svr.predict(xtest)

# %%
from sklearn.metrics import mean_squared_error as mse 
np.sqrt(mse(ypred,ytest))
# Out:
# 0.29788050023490326

# %%
ypred
# Out:
# array([0.09885991, 0.09886033, 0.09886075, ..., 0.09833916, 0.09833955,
#        0.09832757])

# %%
ytest
# Out:
#          Close
# 6199  0.093553
# 6200  0.094470
# 6201  0.096417
# 6202  0.095997
# 6203  0.097181
# ...        ...
# 8852  1.000000
# 8853  0.971705
# 8854  0.963877
# 8855  0.962616
# 8856  0.961394
#
# [2658 rows x 1 columns]

# %%
svr.score(xtrain,ytrain),svr.score(xtest,ytest)
# Out:
# (-0.4601205043104635, -0.7603073004515652)

# %%
#svr_poly=SVR(kernel='poly',degree=2)
#svr_poly.fit(xtrain,ytrain)

# %%
# ypred2

# %%
svr_poly3=SVR(kernel='poly',degree=8)
svr_poly3.fit(xtrain,ytrain)
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\sklearn\utils\validation.py:72: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(**kwargs)
# SVR(degree=8, kernel='poly')

# %%
ypred3=svr_poly3.predict(xtest)
np.sqrt(mse(ypred3,ytest))
# Out:
# 0.2532027628162339

# %%
ypred3
# Out:
# array([0.15100272, 0.15102391, 0.15104512, ..., 0.1784115 , 0.17843316,
#        0.17813931])

# %%
ytest
# Out:
#          Close
# 6199  0.093553
# 6200  0.094470
# 6201  0.096417
# 6202  0.095997
# 6203  0.097181
# ...        ...
# 8852  1.000000
# 8853  0.971705
# 8854  0.963877
# 8855  0.962616
# 8856  0.961394
#
# [2658 rows x 1 columns]

# %%
svr_poly3.score(xtest,ytest)
# Out:
# -0.27186560086258127

# %%
svr_poly3.score(xtrain,ytrain)
# Out:
# -0.7061606153136353

# %%
import pickle
pickle.dump(svr_poly3,open('model.pkl','wb'))

# %% [markdown]
# # Using High as output

# %%
y1=data_new[['High']]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y1,test_size=0.3,shuffle=False)
svr_poly_high=SVR(kernel='poly',degree=8)
svr_poly_high.fit(x_train,y_train)

# %%
ypred_high=svr_poly_high.predict(x_test)
svr_poly_high.score(x_train,y_train),svr_poly_high.score(x_test,y_test)

# %%
ypred_high,y_test

# %%
pickle.dump(svr_poly_high,open('model_high.pkl','wb'))

# %% [markdown]
# # Using Low for target

# %%
y2=data_new[['Low']]

# %%
xtrainn,xtestt,ytrainn,ytestt=train_test_split(x,y2,test_size=0.3,shuffle=False)
svr_poly_low=SVR(kernel='poly',degree=8)
svr_poly_low.fit(xtrainn,ytrainn)

# %%
ypred_low=svr_poly_low.predict(xtestt)
svr_poly_low.score(xtrainn,ytrainn),svr_poly_low.score(xtestt,ytestt)

# %%
pickle.dump(svr_poly_high,open('model_low.pkl','wb'))

# %%
ytestt,ypred_low

# %%
model = pickle
